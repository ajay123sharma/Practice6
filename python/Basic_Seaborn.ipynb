# %% [markdown]
# # Seaborn Tutorial

# %% [markdown]
# # Distribution plots - for int and float features
# - distplot-
# - joinplot - bivaraint analysis
# - pairplot - more than 2 features
#
# - univaraint analysis - f1 (one)feature
# - bivaraint analysis - f1, f2 (two) feature
# -
#
# Practise problem on IRIS DataSet

# %%
import seaborn as sns

# %%
# tips dataset
df = sns.load_dataset("tips")

# %%
df.head()

# tip is depended featuer
# independed feature sex day total bill
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# # Correlation with Heatmap¶
# A correlation heatmap uses colored cells, typically in a monochromatic scale, to show a 2D correlation matrix (table) between two discrete dimensions or event types. It is very important in Feature Selection

# %%
# correlation only int and float featuer value not category value
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# # Univariate Analysis - 2 features jointplot

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

#pdf curvi line. regresion line

# %% [markdown]
# # Pair Plot - more than 2 feature
# A “pairs plot” is also known as a scatterplot, in which one variable in the same data row is matched with another variable's value, like this: Pairs plots are just elaborations on this, showing all variables paired with all the other variables

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='smoker')

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# # Dist plot
# Dist plot helps us to check the distribution of the columns feature

# %%
sns.distplot(df['tip'])
# kde is by default true then show in percentile

# %%
sns.distplot(df['tip'],kde=False,bins=10)

# %% [markdown]
# # Categorical Plots
# Seaborn also helps us in doing the analysis on Categorical Data points. In this section we will discuss about
# categrial data not int or float
#
# - boxplot
# - violinplot
# - countplot
# - bar plot

# %%
# count plot- Show the counts of observations in each categorical bin using bars.

sns.countplot('sex',data=df)

# %%
sns.countplot('smoker',data=df)

# %%
sns.countplot('day',data=df)

# %%
sns.countplot(y='sex',data=df)
# count number of bill based on sex column total bill

# %%
## Bar Plot - take 2 value instead 1 like countplot
## univariant features
sns.barplot(x='smoker', y='total_bill', data=df)

# %%
sns.barplot(x='sex', y='total_bill', data=df)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Box plot
# A box and whisker plot (sometimes called a boxplot) is a graph that presents information from a five-number summary.

# %% [markdown]
# - dot that outside graph value called outliers

# %%
# Draw a box plot to show distributions with respect to categories.
sns.boxplot('smoker', 'total_bill', data=df)

# %%
sns.boxplot(x='sex', y='total_bill', data=df)
# y axis is percentile

# %%
sns.boxplot(x='day', y='total_bill',data=df)

# %%
# palette change color of box pl ot
sns.boxplot(x='day', y='total_bill', data=df, palette='rainbow')

# %%
sns.boxplot(data=df, orient='v')
# by default take all features

# %%
# categorize my data based on some other categories

sns.boxplot(x='total_bill', y='day', hue='smoker', data=df)

# compare wrt hue value which is smoker

# %% [markdown]
# # Violin Plot
# Violin plot helps us to see both the distribution of data in terms of Kernel density estimation and the box plot

# %%
sns.violinplot(x='total_bill', y='day', data=df, palette='rainbow')

# %%
# Practise Homework

irisi = sns.load_dataset('iris')

# %%
irisi.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
