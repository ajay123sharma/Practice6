# %% [markdown]
# # MatplotLib Tutorial
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# - Generally easy to get started for simple plots
# - Support for custom labels and texts
# - Great control of every element in a figure
# - High-quality output in many formats
# - Very customizable in general

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %%
# simple Example

x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
##plotting using matplotlib 

##plt scatter

plt.scatter(x,y,c='g')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.title("Graph in 2D")
plt.savefig('tg.png')

# %%
y=x*x

# %%
## plt plt

#plt.plot(x,y) ro,r--,r*-,ro,ro--
plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=12)
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %%
## Creating Subplots subplot(nrows, ncols, index, **kwargs)

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'ro')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 

# Plot the points using matplotlib 
plt.plot(x, y)
plt.show()

# %%
x = np.arange(1,11)
y = 3*x + 5
plt.title('Matplotlib Demo')
plt.xlabel('x axis caption')
plt.ylabel('y axis caption')
plt.plot(x,y)
plt.show()

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  

# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
# Show the figure. 
plt.show()

# %%
# Bar plot

x1 = [2,8,10]
y1 = [11,16,9]

x2 = [3,9,11]
y2 = [6,15,7]
plt.bar(x1,y1,color='b')
plt.bar(x2,y2,color='g')
plt.title('Bar Graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.show()

# %% [markdown]
# # Histograms

# %%
#default bins=10 y=density x=number differece
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a,bins=10)
plt.title('Histogram')

plt.show()

# %% [markdown]
# # Box Plot using Matplotlib
# - helps to find out percentiles

# %%
data = [np.random.normal(0, std, 100) for std in range(1,4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %%
data
# Out:
# [array([-1.29216587,  0.19138514,  1.03535604, -1.24053805,  1.22600698,
#          1.80584095,  0.97605052, -0.81810839,  1.26982216, -0.3425209 ,
#          0.03923291,  0.20949712, -0.50077826, -0.06806494, -0.45671563,
#         -0.42039685, -0.5370339 ,  0.18514958,  0.28096919, -0.67468436,
#         -1.2707509 ,  1.25516906, -0.61555949, -0.45216444, -0.11994399,
#         -1.00996814, -1.0708063 , -1.81491552,  0.24405241, -0.20818845,
#         -0.11311471,  1.06279774,  1.39047198,  1.07751035,  0.45429544,
#         -1.24899624,  1.09503557, -0.51683948, -1.17957917, -0.4934445 ,
#          0.44920408, -0.75125442, -0.80909286, -0.62435262, -1.02475385,
#          1.66489833, -1.19870591, -0.03396253,  0.1186114 , -1.0849748 ,
#         -0.51958447,  0.28669881, -1.42981357,  0.21053503, -2.75320165,
#         -1.65079354,  0.65858508,  0.22805333, -1.68481384, -1.44394169,
#         -0.15600539, -0.72641509,  2.57210888, -0.19416714,  1.56532803,
#          0.75483865, -0.86688575,  0.35444969, -0.69835152, -1.18654695,
#         -0.13979148,  0.30501157, -0.13070271,  0.14512729,  0.84875413,
#         -1.69893804,  1.14655974,  0.05803246, -0.4563718 ,  1.20775922,
#         -0.34632553,  1.20699117,  0.24178464, -0.19880596, -0.25755018,
#          0.67554038,  0.93855955,  0.20427765, -0.82070153, -0.75163363,
#          0.57487709,  0.56635683, -1.3266846 ,  0.34336644,  0.32999927,
#         -0.13825081, -1.7876744 ,  0.33802752,  0.92175007, -0.24097643]),
#  array([ 2.67253203,  0.71687428,  0.71696676,  0.23475874,  3.01420713,
#          1.13164868,  3.44680356,  2.66926938, -1.97581664,  1.67671991,
#         -2.82225832,  0.13929048, -0.22155905,  0.21009545, -0.17529837,
#          1.30964914, -1.51487096,  1.49379713,  0.10409361,  0.8986992 ,
#          1.74574984,  0.35561462,  3.5763634 , -1.03762121,  2.77140176,
#         -0.34419174,  0.98296967,  0.02248391,  1.02198059,  1.33958297,
